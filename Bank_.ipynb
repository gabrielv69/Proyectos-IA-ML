# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('Bank.csv')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  ...  IsActiveMember EstimatedSalary Exited
# 0             1    15634602   Hargrave  ...               1       101348.88      1
# 1             2    15647311       Hill  ...               1       112542.58      0
# 2             3    15619304       Onio  ...               0       113931.57      1
# 3             4    15701354       Boni  ...               0        93826.63      0
# 4             5    15737888   Mitchell  ...               1        79084.10      0
# ...         ...         ...        ...  ...             ...             ...    ...
# 9995       9996    15606229   Obijiaku  ...               0        96270.64      0
# 9996       9997    15569892  Johnstone  ...               1       101699.77      0
# 9997       9998    15584532        Liu  ...               1        42085.58      1
# 9998       9999    15682355  Sabbatini  ...               0        92888.52      1
# 9999      10000    15628319     Walker  ...               0        38190.78      0
#
# [10000 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId  ...  EstimatedSalary        Exited
# count  10000.00000  1.000000e+04  ...     10000.000000  10000.000000
# mean    5000.50000  1.569094e+07  ...    100090.239881      0.203700
# std     2886.89568  7.193619e+04  ...     57510.492818      0.402769
# min        1.00000  1.556570e+07  ...        11.580000      0.000000
# 25%     2500.75000  1.562853e+07  ...     51002.110000      0.000000
# 50%     5000.50000  1.569074e+07  ...    100193.915000      0.000000
# 75%     7500.25000  1.575323e+07  ...    149388.247500      0.000000
# max    10000.00000  1.581569e+07  ...    199992.480000      1.000000
#
# [8 rows x 11 columns]

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f42bf5b1150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42c016f7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42c024a190>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f42bffa0b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42bfa51a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42bf4b7550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f42bf3d0fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42bf38b690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42bf38b6d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f42bf340e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42bf2b9a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42bf27b150>]],
#       dtype=object)

# %%
sns.set(style='whitegrid',font_scale=1)
plt.figure(figsize=(15,15))
plt.title('Pearson')
sns.heatmap(df.corr(),vmax=0.6,square=True,cmap='GnBu',linecolor='b',annot=True,annot_kws={"size":8})

# %%
df.loc[df.HasCrCard == 0, 'HasCrCard'] = -1
df.loc[df.IsActiveMember == 0, 'IsActiveMember'] = -1

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  ...  IsActiveMember EstimatedSalary Exited
# 0             1    15634602   Hargrave  ...               1       101348.88      1
# 1             2    15647311       Hill  ...               1       112542.58      0
# 2             3    15619304       Onio  ...              -1       113931.57      1
# 3             4    15701354       Boni  ...              -1        93826.63      0
# 4             5    15737888   Mitchell  ...               1        79084.10      0
# ...         ...         ...        ...  ...             ...             ...    ...
# 9995       9996    15606229   Obijiaku  ...              -1        96270.64      0
# 9996       9997    15569892  Johnstone  ...               1       101699.77      0
# 9997       9998    15584532        Liu  ...               1        42085.58      1
# 9998       9999    15682355  Sabbatini  ...              -1        92888.52      1
# 9999      10000    15628319     Walker  ...              -1        38190.78      0
#
# [10000 rows x 14 columns]

# %%
df['TenureAge']=df.Tenure/df.Age

# %%
df['BalanceSalary'] = df.Balance/df.EstimatedSalary
df['CreditAge'] = df.CreditScore/df.Age

# %%
sns.set(style='whitegrid',font_scale=1)
plt.figure(figsize=(15,15))
plt.title('Pearson')
sns.heatmap(df.corr(),vmax=0.6,square=True,cmap='GnBu',linecolor='b',annot=True,annot_kws={"size":8})

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f42af33ae10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42af2f4250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42af2988d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42af24df50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f42af20e610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42af1c2c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42af1843d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42af1bc990>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f42af1bc9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42af17d190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42af0e9d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42af0ab450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f42af061ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42af024190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42aefd9810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f42aef8ee90>]],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
#  14  TenureAge        10000 non-null  float64
#  15  BalanceSalary    10000 non-null  float64
#  16  CreditAge        10000 non-null  float64
# dtypes: float64(5), int64(9), object(3)
# memory usage: 1.3+ MB

# %%
df_variables_cont = ['CreditScore','Age','Tenure','Balance','NumOfProducts','EstimatedSalary','TenureAge','BalanceSalary','CreditAge']
df_variables_cat = ['Geography','Gender','HasCrCard','IsActiveMember']

# %%
df_aux = df[['Exited']+df_variables_cont+df_variables_cat]

# %%
df_aux
# Out:
#       Exited  CreditScore  Age  ...  Gender  HasCrCard  IsActiveMember
# 0          1          619   42  ...  Female          1               1
# 1          0          608   41  ...  Female         -1               1
# 2          1          502   42  ...  Female          1              -1
# 3          0          699   39  ...  Female         -1              -1
# 4          0          850   43  ...  Female          1               1
# ...      ...          ...  ...  ...     ...        ...             ...
# 9995       0          771   39  ...    Male          1              -1
# 9996       0          516   35  ...    Male          1               1
# 9997       1          709   36  ...  Female         -1               1
# 9998       1          772   42  ...    Male          1              -1
# 9999       0          792   28  ...  Female          1              -1
#
# [10000 rows x 14 columns]

# %%
le = LabelEncoder()
df_aux['Gender'] = le.fit_transform(df_aux['Gender'])
df_aux['Geography'] = le.fit_transform(df_aux['Geography'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_aux
# Out:
#       Exited  CreditScore  Age  ...  Gender  HasCrCard  IsActiveMember
# 0          1          619   42  ...       0          1               1
# 1          0          608   41  ...       0         -1               1
# 2          1          502   42  ...       0          1              -1
# 3          0          699   39  ...       0         -1              -1
# 4          0          850   43  ...       0          1               1
# ...      ...          ...  ...  ...     ...        ...             ...
# 9995       0          771   39  ...       1          1              -1
# 9996       0          516   35  ...       1          1               1
# 9997       1          709   36  ...       0         -1               1
# 9998       1          772   42  ...       1          1              -1
# 9999       0          792   28  ...       0          1              -1
#
# [10000 rows x 14 columns]

# %%
scaler = MinMaxScaler()
df_aux[df_variables_cont] = scaler.fit_transform(df_aux[df_variables_cont])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
X = df_aux.drop('Exited',axis=1)
y = df_aux['Exited']

# %%
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size=0.3,random_state = 10)

# %%
model = Sequential()
model.add(Dense(12,activation='relu'))#,input_dim=13
model.add(Dense(7,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer = 'adam', loss='binary_crossentropy', metrics = ['accuracy'])

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test.values),batch_size=10,epochs=40,verbose=1)
# Out:
# Epoch 1/40
# 700/700 [==============================] - 2s 2ms/step - loss: 0.5099 - accuracy: 0.7963 - val_loss: 0.4788 - val_accuracy: 0.7933
# Epoch 2/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.4705 - accuracy: 0.7952 - val_loss: 0.4603 - val_accuracy: 0.7933
# Epoch 3/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.4443 - accuracy: 0.8007 - val_loss: 0.4489 - val_accuracy: 0.8010
# Epoch 4/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.4200 - accuracy: 0.8192 - val_loss: 0.4402 - val_accuracy: 0.8113
# Epoch 5/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.4266 - accuracy: 0.8186 - val_loss: 0.4365 - val_accuracy: 0.8110
# Epoch 6/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.4180 - accuracy: 0.8280 - val_loss: 0.4320 - val_accuracy: 0.8207
# Epoch 7/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.4212 - accuracy: 0.8292 - val_loss: 0.4306 - val_accuracy: 0.8203
# Epoch 8/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.4086 - accuracy: 0.8280 - val_loss: 0.4286 - val_accuracy: 0.8233
# Epoch 9/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.4106 - accuracy: 0.8372 - val_loss: 0.4266 - val_accuracy: 0.8253
# Epoch 10/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.4048 - accuracy: 0.8318 - val_loss: 0.4246 - val_accuracy: 0.8293
# Epoch 11/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.4017 - accuracy: 0.8404 - val_loss: 0.4240 - val_accuracy: 0.8287
# Epoch 12/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.4014 - accuracy: 0.8386 - val_loss: 0.4097 - val_accuracy: 0.8353
# Epoch 13/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3800 - accuracy: 0.8541 - val_loss: 0.4066 - val_accuracy: 0.8407
# Epoch 14/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3809 - accuracy: 0.8499 - val_loss: 0.3973 - val_accuracy: 0.8477
# Epoch 15/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3697 - accuracy: 0.8529 - val_loss: 0.3973 - val_accuracy: 0.8393
# Epoch 16/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3677 - accuracy: 0.8541 - val_loss: 0.3877 - val_accuracy: 0.8520
# Epoch 17/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3511 - accuracy: 0.8638 - val_loss: 0.3839 - val_accuracy: 0.8473
# Epoch 18/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3449 - accuracy: 0.8626 - val_loss: 0.3807 - val_accuracy: 0.8527
# Epoch 19/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3517 - accuracy: 0.8580 - val_loss: 0.3782 - val_accuracy: 0.8533
# Epoch 20/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3448 - accuracy: 0.8618 - val_loss: 0.3775 - val_accuracy: 0.8507
# Epoch 21/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3629 - accuracy: 0.8520 - val_loss: 0.3763 - val_accuracy: 0.8517
# Epoch 22/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3508 - accuracy: 0.8605 - val_loss: 0.3753 - val_accuracy: 0.8507
# Epoch 23/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3462 - accuracy: 0.8616 - val_loss: 0.3712 - val_accuracy: 0.8527
# Epoch 24/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3549 - accuracy: 0.8552 - val_loss: 0.3769 - val_accuracy: 0.8463
# Epoch 25/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3512 - accuracy: 0.8625 - val_loss: 0.3716 - val_accuracy: 0.8513
# Epoch 26/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3494 - accuracy: 0.8580 - val_loss: 0.3707 - val_accuracy: 0.8533
# Epoch 27/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3393 - accuracy: 0.8689 - val_loss: 0.3726 - val_accuracy: 0.8517
# Epoch 28/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3344 - accuracy: 0.8670 - val_loss: 0.3707 - val_accuracy: 0.8510
# Epoch 29/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3398 - accuracy: 0.8630 - val_loss: 0.3669 - val_accuracy: 0.8523
# Epoch 30/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3341 - accuracy: 0.8678 - val_loss: 0.3702 - val_accuracy: 0.8507
# Epoch 31/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3423 - accuracy: 0.8607 - val_loss: 0.3683 - val_accuracy: 0.8500
# Epoch 32/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3168 - accuracy: 0.8756 - val_loss: 0.3697 - val_accuracy: 0.8527
# Epoch 33/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3498 - accuracy: 0.8571 - val_loss: 0.3670 - val_accuracy: 0.8517
# Epoch 34/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3363 - accuracy: 0.8686 - val_loss: 0.3655 - val_accuracy: 0.8510
# Epoch 35/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3273 - accuracy: 0.8669 - val_loss: 0.3656 - val_accuracy: 0.8513
# Epoch 36/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3499 - accuracy: 0.8601 - val_loss: 0.3658 - val_accuracy: 0.8527
# Epoch 37/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3362 - accuracy: 0.8688 - val_loss: 0.3681 - val_accuracy: 0.8530
# Epoch 38/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3428 - accuracy: 0.8623 - val_loss: 0.3668 - val_accuracy: 0.8513
# Epoch 39/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3427 - accuracy: 0.8561 - val_loss: 0.3694 - val_accuracy: 0.8497
# Epoch 40/40
# 700/700 [==============================] - 1s 2ms/step - loss: 0.3258 - accuracy: 0.8761 - val_loss: 0.3662 - val_accuracy: 0.8530

# %%
loss = pd.DataFrame(model.history.history)
plt.figure(figsize=(15,5))
sns.lineplot(data=loss,lw=3)
sns.despine()

# %%
svm = SVC(kernel='linear',verbose=True)
svm.fit(X_train,y_train)
# Out:
# [LibSVM]
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=True)

# %%
svm.score(X_train,y_train)
# Out:
# 0.7975714285714286

# %%
svm.score(X_test,y_test)
# Out:
# 0.7933333333333333

# %%
error = []
for n in range(1,50):
  knn = KNeighborsClassifier(n_neighbors=n)
  knn.fit(X_train,y_train)
  predic_n = knn.predict(X_test)
  error.append(np.mean(predic_n != y_test))

# %%
plt.figure(figsize=(15,10))
plt.plot(range(1,50),error,color='b',linestyle='dashed',marker='o',markerfacecolor ='b')

# %%
knn_c = KNeighborsClassifier(n_neighbors=8)
knn_c.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=8, p=2,
#                      weights='uniform')

# %%
y_pred_Train = knn_c.predict(X_train)
y_pred_Test = knn_c.predict(X_test)

# %%
print(accuracy_score(y_train,y_pred_Train))
print(accuracy_score(y_test,y_pred_Test))
# Out:
# 0.8442857142857143
# 0.814
